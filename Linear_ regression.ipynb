# %%
import matplotlib.pyplot as plt
slope = 2
intercept = 1
def myfunc(x):
    return slope * x + intercept
x = [1, 2, 3, 4, 5]
y = [3, 5, 7, 9, 11] 
mymodel = list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
